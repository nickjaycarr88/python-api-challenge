# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = list(zip(lats, lngs))

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 617

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# %%
# city = "saldanha"
city_url = url + "&q=" + city.replace(" ","+")

# %%
response = requests.get(city_url)

# %%
response.status_code
# Out:
# 200

# %%
response = response.json()

# %%
city_name = []
latitude_list = []
longitude_list = []
max_temp_list = []
humidity_list = []
cloudiness_list = []
wind_speed_list = []
country = []
date_list = []

# %%
for city in cities:
    city_url = url + "&q=" + city.replace(" ","+")
    response = requests.get(city_url).json()
    
    try:
        
        
        latitude = response["coord"]["lat"]
        latitude_list.append(latitude)
        
        longitude = response["coord"]["lon"]
        longitude_list.append(longitude)
        
        max_temp = response["main"]["temp_max"]
        max_temp_list.append(max_temp)
        
        humidity = response["main"]["humidity"]
        humidity_list.append(humidity)
        
        cloudiness = response["clouds"]['all']
        cloudiness_list.append(cloudiness)
        
        wind_speed = response["wind"]["speed"]
        wind_speed_list.append(wind_speed)
        
        country_name = response["sys"]["country"]
        country.append(country_name)
        
        date = response["dt"]
        date_list.append(date)
        
        city_iterate = city
        city_name.append(city_iterate)
        
        print(f"Processing Record {cities.index(city)+1} of Set 1 | {city}")
    
    except:
        print("City not found. Skipping...")
        pass
# Out:
# Processing Record 1 of Set 1 | tiksi
# Processing Record 2 of Set 1 | mar del plata
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | qaanaaq
# Processing Record 5 of Set 1 | hithadhoo
# Processing Record 6 of Set 1 | tautira
# Processing Record 7 of Set 1 | alofi
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | new norfolk
# Processing Record 10 of Set 1 | upernavik
# Processing Record 11 of Set 1 | honjo
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | barrow
# Processing Record 14 of Set 1 | namibe
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | sao filipe
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | husavik
# Processing Record 19 of Set 1 | mahebourg
# Processing Record 20 of Set 1 | pandharpur
# Processing Record 21 of Set 1 | berlevag
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | tuktoyaktuk
# Processing Record 24 of Set 1 | thessalon
# Processing Record 25 of Set 1 | hue
# Processing Record 26 of Set 1 | avarua
# Processing Record 27 of Set 1 | puerto del rosario
# Processing Record 28 of Set 1 | hobyo
# Processing Record 29 of Set 1 | bethel
# Processing Record 30 of Set 1 | rawson
# Processing Record 31 of Set 1 | yellowknife
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | saint george
# Processing Record 34 of Set 1 | vaini
# Processing Record 35 of Set 1 | lebu
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | kodiak
# Processing Record 40 of Set 1 | taoudenni
# Processing Record 41 of Set 1 | san andres
# Processing Record 42 of Set 1 | atuona
# Processing Record 43 of Set 1 | kapaa
# Processing Record 44 of Set 1 | hilo
# City not found. Skipping...
# Processing Record 46 of Set 1 | platteville
# Processing Record 47 of Set 1 | ushuaia
# City not found. Skipping...
# Processing Record 49 of Set 1 | lorengau
# Processing Record 50 of Set 1 | palauig
# Processing Record 51 of Set 1 | codrington
# City not found. Skipping...
# Processing Record 53 of Set 1 | kuytun
# Processing Record 54 of Set 1 | cape town
# City not found. Skipping...
# Processing Record 56 of Set 1 | ilulissat
# Processing Record 57 of Set 1 | cabo san lucas
# Processing Record 58 of Set 1 | san patricio
# Processing Record 59 of Set 1 | butaritari
# Processing Record 60 of Set 1 | vila velha
# Processing Record 61 of Set 1 | kayerkan
# Processing Record 62 of Set 1 | pevek
# Processing Record 63 of Set 1 | san cristobal
# Processing Record 64 of Set 1 | east london
# Processing Record 65 of Set 1 | orzinuovi
# Processing Record 66 of Set 1 | carnarvon
# Processing Record 67 of Set 1 | port alfred
# Processing Record 68 of Set 1 | belyy yar
# Processing Record 69 of Set 1 | kyshtovka
# Processing Record 70 of Set 1 | ulvila
# Processing Record 71 of Set 1 | adrar
# Processing Record 72 of Set 1 | west wendover
# Processing Record 73 of Set 1 | jamestown
# Processing Record 74 of Set 1 | talnakh
# City not found. Skipping...
# Processing Record 76 of Set 1 | haines junction
# Processing Record 77 of Set 1 | albany
# City not found. Skipping...
# Processing Record 79 of Set 1 | ekibastuz
# Processing Record 80 of Set 1 | te anau
# Processing Record 81 of Set 1 | khatanga
# Processing Record 82 of Set 1 | port hedland
# Processing Record 83 of Set 1 | oussouye
# Processing Record 84 of Set 1 | kathmandu
# Processing Record 85 of Set 1 | chuy
# Processing Record 86 of Set 1 | veraval
# Processing Record 87 of Set 1 | wakkanai
# Processing Record 88 of Set 1 | yuli
# Processing Record 89 of Set 1 | hobart
# Processing Record 90 of Set 1 | bambous virieux
# Processing Record 91 of Set 1 | esso
# Processing Record 92 of Set 1 | itarema
# Processing Record 93 of Set 1 | tomatlan
# Processing Record 94 of Set 1 | goderich
# Processing Record 95 of Set 1 | puerto varas
# Processing Record 570 of Set 1 | karoi
# City not found. Skipping...
# Processing Record 572 of Set 1 | zomin
# Processing Record 573 of Set 1 | zhangye
# Processing Record 574 of Set 1 | ixtapa
# Processing Record 575 of Set 1 | kiunga
# Processing Record 576 of Set 1 | mudu
# City not found. Skipping...
# Processing Record 578 of Set 1 | noyabrsk
# Processing Record 579 of Set 1 | punta alta
# Processing Record 580 of Set 1 | manakara
# Processing Record 581 of Set 1 | senno
# Processing Record 582 of Set 1 | pak chong
# Processing Record 583 of Set 1 | batemans bay
# Processing Record 584 of Set 1 | katangli
# Processing Record 585 of Set 1 | zhezkazgan
# Processing Record 586 of Set 1 | saint-pierre
# Processing Record 587 of Set 1 | jiblah
# Processing Record 588 of Set 1 | katastarion
# Processing Record 589 of Set 1 | wucheng
# Processing Record 590 of Set 1 | baykit
# Processing Record 591 of Set 1 | presidente dutra
# Processing Record 592 of Set 1 | martil
# City not found. Skipping...
# Processing Record 594 of Set 1 | bandiagara
# Processing Record 595 of Set 1 | lucea
# Processing Record 596 of Set 1 | kismayo
# Processing Record 597 of Set 1 | waingapu
# Processing Record 598 of Set 1 | kerman
# Processing Record 599 of Set 1 | mendi
# Processing Record 600 of Set 1 | kapit
# Processing Record 601 of Set 1 | monster
# City not found. Skipping...
# Processing Record 603 of Set 1 | jinxiang
# Processing Record 604 of Set 1 | aksha
# Processing Record 605 of Set 1 | pestovo
# Processing Record 606 of Set 1 | adilcevaz
# Processing Record 607 of Set 1 | charlestown
# Processing Record 608 of Set 1 | matveyevka
# Processing Record 609 of Set 1 | marawi
# City not found. Skipping...
# Processing Record 611 of Set 1 | shambu
# Processing Record 612 of Set 1 | saint-francois
# Processing Record 613 of Set 1 | sumbe
# Processing Record 614 of Set 1 | debre tabor
# Processing Record 615 of Set 1 | nome
# Processing Record 616 of Set 1 | golden
# Processing Record 617 of Set 1 | arlit

# %%
#put collected data into a dataframe
weather_dict = {
    "City": city_name,
    "Lat": latitude_list,
    "Lng": longitude_list,
    "Max Temp": max_temp_list,
    "Humidity": humidity_list,
    "Cloudiness": cloudiness_list,
    "Wind Speed": wind_speed_list,
    "Country": country,
    "Date": date_list
}
weather_data = pd.DataFrame(weather_dict)

# %%
weather_data.to_csv("weather data.csv", index=False)

# %%
weather_data["Max Temp"] = ((weather_data["Max Temp"] - 32) * 5/9).round(2)

# %%
weather_data
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            tiksi  71.6872  128.8694     12.17        59         100
# 1    mar del plata -38.0023  -57.5575     10.05        86           0
# 2     punta arenas -53.1500  -70.9167      5.06        80         100
# 3          qaanaaq  77.4840  -69.3632      1.71        65          30
# 4        hithadhoo  -0.6000   73.0833     27.75        73           1
# ..             ...      ...       ...       ...       ...         ...
# 562          sumbe -11.2061   13.8437     19.25        95          36
# 563    debre tabor  11.8500   38.0167     10.77        96         100
# 564           nome  64.5011 -165.4064     11.20        82         100
# 565         golden  39.7555 -105.2211     32.79        28           5
# 566          arlit  18.7369    7.3853     34.71        28          21
#
#      Wind Speed Country        Date
# 0          4.94      RU  1660179645
# 1         10.36      AR  1660179525
# 2          4.94      CL  1660179647
# 3          4.72      GL  1660179647
# 4          9.86      MV  1660179648
# ..          ...     ...         ...
# 562        8.01      AO  1660180115
# 563        0.94      ET  1660180116
# 564        8.05      US  1660180117
# 565        3.00      US  1660180117
# 566        6.82      NE  1660180118
#
# [567 rows x 9 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#export to csv
weather_data.to_csv("weather data.csv", index=False)

# %%
#Display dataframe
weather_data.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          tiksi  71.6872  128.8694     12.17        59         100
# 1  mar del plata -38.0023  -57.5575     10.05        86           0
# 2   punta arenas -53.1500  -70.9167      5.06        80         100
# 3        qaanaaq  77.4840  -69.3632      1.71        65          30
# 4      hithadhoo  -0.6000   73.0833     27.75        73           1
#
#    Wind Speed Country        Date
# 0        4.94      RU  1660179645
# 1       10.36      AR  1660179525
# 2        4.94      CL  1660179647
# 3        4.72      GL  1660179647
# 4        9.86      MV  1660179648

# %%
cities
# Out:
# ['tiksi',
#  'mar del plata',
#  'punta arenas',
#  'qaanaaq',
#  'hithadhoo',
#  'tautira',
#  'alofi',
#  'bredasdorp',
#  'new norfolk',
#  'upernavik',
#  'honjo',
#  'puerto ayora',
#  'barrow',
#  'namibe',
#  'busselton',
#  'sao filipe',
#  'hermanus',
#  'husavik',
#  'mahebourg',
#  'pandharpur',
#  'berlevag',
#  'mataura',
#  'tuktoyaktuk',
#  'thessalon',
#  'hue',
#  'avarua',
#  'puerto del rosario',
#  'hobyo',
#  'bethel',
#  'rawson',
#  'yellowknife',
#  'bluff',
#  'saint george',
#  'vaini',
#  'lebu',
#  'saleaula',
#  'belushya guba',
#  'rikitea',
#  'kodiak',
#  'taoudenni',
#  'san andres',
#  'atuona',
#  'kapaa',
#  'hilo',
#  'barentsburg',
#  'platteville',
#  'ushuaia',
#  'illoqqortoormiut',
#  'lorengau',
#  'palauig',
#  'codrington',
#  'mys shmidta',
#  'kuytun',
#  'cape town',
#  'vaitupu',
#  'ilulissat',
#  'cabo san lucas',
#  'san patricio',
#  'butaritari',
#  'vila velha',
#  'kayerkan',
#  'pevek',
#  'san cristobal',
#  'east london',
#  'orzinuovi',
#  'carnarvon',
#  'port alfred',
#  'belyy yar',
#  'kyshtovka',
#  'ulvila',
#  'adrar',
#  'west wendover',
#  'jamestown',
#  'talnakh',
#  'grand river south east',
#  'haines junction',
#  'albany',
#  'taolanaro',
#  'ekibastuz',
#  'te anau',
#  'khatanga',
#  'port hedland',
#  'oussouye',
#  'kathmandu',
#  'chuy',
#  'veraval',
#  'wakkanai',
#  'yuli',
#  'hobart',
#  'bambous virieux',
#  'esso',
#  'itarema',
#  'tomatlan',
#  'goderich',
#  'puerto varas',
#  'marcona',
#  'san antonio',
#  'pangkalanbuun',
#  'tumannyy',
#  'pimentel',
#  'esperance',
#  'aksu',
#  'socuellamos',
#  'nakskov',
#  'bowen',
#  'tsihombe',
#  'san carlos de bariloche',
#  'northam',
#  'cockburn town',
#  'menomonie',
#  'haibowan',
#  'alberton',
#  'porto torres',
#  'margate',
#  'port blair',
#  'naze',
#  'kharan',
#  'verkhnevilyuysk',
#  'orlik',
#  'ormara',
#  'gawler',
#  'nanortalik',
#  'sembe',
#  'kimbe',
#  'cayenne',
#  'stromness',
#  'katsuura',
#  'yulara',
#  'bulgan',
#  'zhangjiakou',
#  'sveti nikole',
#  'buraydah',
#  'campina verde',
#  'coihaique',
#  'olafsvik',
#  'gobabis',
#  'moses lake',
#  'anadyr',
#  'gillette',
#  'nikolskoye',
#  'kazachinskoye',
#  'linqing',
#  'victoria',
#  'sentyabrskiy',
#  'kindu',
#  'iturama',
#  'tucuman',
#  'port elizabeth',
#  'fort-shevchenko',
#  'betioky',
#  'airai',
#  'sorland',
#  'umzimvubu',
#  'faanui',
#  'taltal',
#  'tasiilaq',
#  'cidreira',
#  'carmen',
#  'muros',
#  'la ronge',
#  'caxito',
#  'argelia',
#  'hay river',
#  'bengkulu',
#  'bilibino',
#  'killybegs',
#  'cerritos',
#  'luderitz',
#  'vrangel',
#  'saldanha',
#  'san luis',
#  'asau',
#  'batagay',
#  'fujinomiya',
#  'huarmey',
#  'colac',
#  'road town',
#  'nyimba',
#  'saint-leu',
#  'tartus',
#  'darnah',
#  'rio grande',
#  'vestmannaeyjar',
#  'sinnamary',
#  'calatayud',
#  'kolondieba',
#  'havoysund',
#  'beloha',
#  'caravelas',
#  'lalomanu',
#  'port hawkesbury',
#  'chokurdakh',
#  'porto walter',
#  'bargal',
#  'lompoc',
#  'seoul',
#  'okhotsk',
#  'lagoa',
#  'belaya gora',
#  'kamogata',
#  'oktyabrskoye',
#  'zabol',
#  'tianpeng',
#  'severo-kurilsk',
#  'nizhniy odes',
#  'valparaiso',
#  'marzuq',
#  'cherskiy',
#  'maun',
#  'dunmore east',
#  'micheweni',
#  'ancud',
#  'kenai',
#  'yinchuan',
#  'pemangkat',
#  'brownwood',
#  'samusu',
#  'sulangan',
#  'rock sound',
#  'uzumlu',
#  'kuruman',
#  'oytal',
#  'fuerte olimpo',
#  'lavrentiya',
#  'kidal',
#  'hofn',
#  'bathsheba',
#  'bonthe',
#  'sorong',
#  'kavieng',
#  'pirot',
#  'ndele',
#  'gusau',
#  'aykhal',
#  'hagavik',
#  'mehamn',
#  'ribeira grande',
#  'attawapiskat',
#  'longyearbyen',
#  'baherden',
#  'talcahuano',
#  'tura',
#  'kieta',
#  'lander',
#  'akonolinga',
#  'baiao',
#  'liberal',
#  'hirara',
#  'shchelyayur',
#  'iqaluit',
#  'pokrovsk',
#  'provideniya',
#  'saskylakh',
#  'taksimo',
#  'fortuna',
#  'geresk',
#  'shache',
#  'fairlie',
#  'sylacauga',
#  'leningradskiy',
#  'nizhneyansk',
#  'yining',
#  'napier',
#  'buenos aires',
#  'montrose',
#  'tilichiki',
#  'galgani',
#  'kyrylivka',
#  'yar-sale',
#  'pryluky',
#  'brigantine',
#  'champerico',
#  'kysyl-syr',
#  'kwinana',
#  'bageshwar',
#  'tuatapere',
#  'bac lieu',
#  'juquitiba',
#  'grand centre',
#  'birao',
#  'karonga',
#  'kargil',
#  'georgetown',
#  'negele',
#  'ampanihy',
#  'catemaco',
#  'balkanabat',
#  'tabiauea',
#  'merauke',
#  'kegayli',
#  'skelleftea',
#  'savonlinna',
#  'jackson',
#  'aliwal north',
#  'nemuro',
#  'saint-philippe',
#  'wattegama',
#  'pisco',
#  'wahiawa',
#  'thinadhoo',
#  'roma',
#  'lata',
#  'arraial do cabo',
#  'arcachon',
#  'belgrade',
#  'kahului',
#  'port macquarie',
#  'den helder',
#  'bontang',
#  'batagay-alyta',
#  'puerto escondido',
#  'komsomolskiy',
#  'katherine',
#  'manzhouli',
#  'zhigansk',
#  'mao',
#  'werda',
#  'benguela',
#  'lawton',
#  'pangnirtung',
#  'leh',
#  'castro',
#  'saint-augustin',
#  'axim',
#  'dikson',
#  'clyde river',
#  'alice springs',
#  'uwajima',
#  'gannan',
#  'faya',
#  'richards bay',
#  'lehola',
#  'mount isa',
#  'blagoyevo',
#  'kamenskoye',
#  'dingle',
#  'kulhudhuffushi',
#  'phan rang',
#  'mashivka',
#  'homer',
#  'shingu',
#  'lieksa',
#  'portlethen',
#  'ilesha',
#  'eyl',
#  'meadow lake',
#  'carlisle',
#  'kljajicevo',
#  'krasnoselkup',
#  'pabianice',
#  'rocha',
#  'jiexiu',
#  'orocue',
#  'waipawa',
#  'maneadero',
#  'egvekinot',
#  'bom jesus',
#  'elliot',
#  'kavaratti',
#  'praia',
#  'ambilobe',
#  'poum',
#  'ngukurr',
#  'kishi',
#  'cravo norte',
#  'jiaozuo',
#  'mineiros',
#  'lolua',
#  'guatire',
#  'ahipara',
#  'aksarka',
#  'labutta',
#  'beringovskiy',
#  'hasaki',
#  'lasa',
#  'baleshwar',
#  'los llanos de aridane',
#  'kaitangata',
#  'whitehorse',
#  'coquimbo',
#  'prieska',
#  'gurgan',
#  'dongying',
#  'toktogul',
#  'liverpool',
#  'srednekolymsk',
#  'riyadh',
#  'frontera',
#  'san policarpo',
#  'santa maria',
#  'swellendam',
#  'aquiraz',
#  'novikovo',
#  'port-cartier',
#  'clevelandia',
#  'pacific grove',
#  'saint-georges',
#  'novyy urengoy',
#  'ouesso',
#  'morant bay',
#  'amderma',
#  'binzhou',
#  'honiara',
#  'norman wells',
#  'zhuhai',
#  'geraldton',
#  'narsaq',
#  'punol',
#  'tiarei',
#  'turukhansk',
#  'sitka',
#  'lashio',
#  'safwah',
#  'grivenskaya',
#  'maningrida',
#  'warqla',
#  'elbistan',
#  'ossora',
#  'lazarev',
#  'progreso',
#  'plouzane',
#  'palabuhanratu',
#  'winona',
#  'maniitsoq',
#  'misratah',
#  'kudahuvadhoo',
#  'joao pinheiro',
#  'prescott',
#  'guerrero negro',
#  'richard toll',
#  'hami',
#  'ambon',
#  'beausejour',
#  'farah',
#  'fuyu',
#  'evansville',
#  'kuragino',
#  'minsk',
#  'ulladulla',
#  'jangipur',
#  'san vicente',
#  'wang saphung',
#  'vernon',
#  'briceni',
#  'petropavlovsk-kamchatskiy',
#  'qaqortoq',
#  'bubaque',
#  'matara',
#  'makakilo city',
#  'nishihara',
#  'abu kamal',
#  'tutzing',
#  'paracuru',
#  'salinopolis',
#  'svetlogorsk',
#  'nagato',
#  'moranbah',
#  'changji',
#  'labuan',
#  'kalianget',
#  'manado',
#  'kondinskoye',
#  'hihifo',
#  'temaraia',
#  'alvand',
#  'ticuantepe',
#  'vardo',
#  'bundaberg',
#  'dzaoudzi',
#  'san juan',
#  'rosarito',
#  'ternate',
#  'ginda',
#  'viedma',
#  'moose factory',
#  'hambantota',
#  'thompson',
#  'zalantun',
#  'taicheng',
#  'zabaykalsk',
#  'fonte boa',
#  'port hardy',
#  'kashi',
#  'syracuse',
#  'kamenka',
#  'portoferraio',
#  'verkhnyaya inta',
#  'gat',
#  'niquelandia',
#  'kaifeng',
#  'ous',
#  'kamaishi',
#  'tibati',
#  'jumla',
#  'aklavik',
#  'borama',
#  'toliary',
#  'puri',
#  'marshall',
#  'snezhnogorsk',
#  'sabinas hidalgo',
#  'pipar',
#  'rey bouba',
#  'nantucket',
#  'ulety',
#  'regen',
#  'sibu',
#  'pila',
#  'raymond',
#  'banda aceh',
#  'rivne',
#  'thanh hoa',
#  'gamba',
#  'la asuncion',
#  'pustoshka',
#  'morgan city',
#  'velasco ibarra',
#  'vung tau',
#  'joshimath',
#  'elizabeth city',
#  'balaipungut',
#  'paamiut',
#  'half moon bay',
#  'kruisfontein',
#  'dudinka',
#  'ponta do sol',
#  'marsa matruh',
#  'inuvik',
#  'nabire',
#  'ituni',
#  'tessalit',
#  'nerchinskiy zavod',
#  'okha',
#  'raga',
#  'dawlatabad',
#  'uvira',
#  'kuhdasht',
#  'camocim',
#  'nuuk',
#  'inirida',
#  'karlivka',
#  'bethune',
#  'pontianak',
#  'tucurui',
#  'quatre cocos',
#  'luangwa',
#  'nanzhou',
#  'salvador',
#  'gorom-gorom',
#  'inhambane',
#  'alyangula',
#  'gurupa',
#  'mogadishu',
#  'klaksvik',
#  'port lincoln',
#  'bay roberts',
#  'bluefield',
#  'cururupu',
#  'sinazongwe',
#  'sompeta',
#  'tazovskiy',
#  'pokanayevka',
#  'lumphat',
#  'rundu',
#  'safaga',
#  'cabinda',
#  'amazar',
#  'constitucion',
#  'stephenville',
#  'karoi',
#  'phnum penh',
#  'zomin',
#  'zhangye',
#  'ixtapa',
#  'kiunga',
#  'mudu',
#  'chagda',
#  'noyabrsk',
#  'punta alta',
#  'manakara',
#  'senno',
#  'pak chong',
#  'batemans bay',
#  'katangli',
#  'zhezkazgan',
#  'saint-pierre',
#  'jiblah',
#  'katastarion',
#  'wucheng',
#  'baykit',
#  'presidente dutra',
#  'martil',
#  'westpunt',
#  'bandiagara',
#  'lucea',
#  'kismayo',
#  'waingapu',
#  'kerman',
#  'mendi',
#  'kapit',
#  'monster',
#  'eldikan',
#  'jinxiang',
#  'aksha',
#  'pestovo',
#  'adilcevaz',
#  'charlestown',
#  'matveyevka',
#  'marawi',
#  'sumbawa',
#  'shambu',
#  'saint-francois',
#  'sumbe',
#  'debre tabor',
#  'nome',
#  'golden',
#  'arlit']

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
#convert all the columns to respective data types
weather_data["Lat"]=weather_data["Lat"].astype(float)
weather_data["Lng"]=weather_data["Lng"].astype(float)
weather_data["Max Temp"]=weather_data["Max Temp"].astype(float)
weather_data["Humidity"]=weather_data["Humidity"].astype(float)
weather_data["Cloudiness"]=weather_data["Cloudiness"].astype(float)
weather_data["Wind Speed"]=weather_data["Wind Speed"].astype(float)
weather_data["Date"]=weather_data["Date"].astype(int)

# %%
weather_data.head(50)
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0
# 48           cape town -33.9258   18.4232     13.48      92.0        97.0
# 49           ilulissat  69.2167  -51.1000      6.01      87.0       100.0
#
#     Wind Speed Country        Date
# 0         4.94      RU  1660179645
# 1        10.36      AR  1660179525
# 2         4.94      CL  1660179647
# 3         4.72      GL  1660179647
# 4         9.86      MV  1660179648
# 5        15.14      PF  1660179649
# 6         9.22      NU  1660179573
# 7         2.39      ZA  1660179438
# 8         2.84      AU  1660179650
# 9         7.29      GL  1660179652
# 10        1.79      JP  1660179653
# 11        8.01      EC  1660179518
# 12       13.80      US  1660179654
# 13        5.14      AO  1660179655
# 14        3.62      AU  1660179656
# 15        7.96      CV  1660179657
# 16        8.68      ZA  1660179658
# 17        5.73      IS  1660179659
# 18       18.97      MU  1660179660
# 19       19.24      IN  1660179661
# 20        4.61      NO  1660179661
# 21        5.64      NZ  1660179517
# 22       17.27      CA  1660179663
# 23       14.38      CA  1660179664
# 24        2.30      VN  1660179624
# 25       16.11      CK  1660179609
# 26       13.80      ES  1660179666
# 27       18.90      SO  1660179667
# 28        1.90      US  1660179646
# 29        7.92      AR  1660179461
# 30       20.56      CA  1660179669
# 31       10.22      NZ  1660179670
# 32        4.00      US  1660179401
# 33       19.57      TO  1660179403
# 34        1.90      CL  1660179673
# 35       22.44      PF  1660179524
# 36        8.05      US  1660179676
# 37        5.64      ML  1660179676
# 38       11.50      CO  1660179572
# 39       21.45      PF  1660179573
# 40        7.00      US  1660179678
# 41        5.01      US  1660179420
# 42        3.44      US  1660179680
# 43        2.30      AR  1660179390
# 44        4.29      PG  1660179682
# 45        7.58      PH  1660179683
# 46       16.93      AU  1660179684
# 47        5.06      RU  1660179686
# 48        3.00      ZA  1660179686
# 49        5.75      GL  1660179688

# %%
#filter Humidity column by values over 100
above100 = weather_data[weather_data["Humidity"]>100]

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
#put these index values into a list
above100_list = list(above100.index.values)
#drop all numbers in the list by index value
clean_city_data = weather_data.drop(above100_list, inplace=False)
#reset the index
clean_city_data.reset_index(inplace=True)
clean_city_data.head(10)
# Out:
#    index           City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      0          tiksi  71.6872  128.8694     12.17      59.0       100.0
# 1      1  mar del plata -38.0023  -57.5575     10.05      86.0         0.0
# 2      2   punta arenas -53.1500  -70.9167      5.06      80.0       100.0
# 3      3        qaanaaq  77.4840  -69.3632      1.71      65.0        30.0
# 4      4      hithadhoo  -0.6000   73.0833     27.75      73.0         1.0
# 5      5        tautira -17.7333 -149.1500     25.08      72.0       100.0
# 6      6          alofi -19.0595 -169.9187     27.94      65.0        40.0
# 7      7     bredasdorp -34.5322   20.0403     12.10      92.0       100.0
# 8      8    new norfolk -42.7826  147.0587     12.18      73.0        97.0
# 9      9      upernavik  72.7868  -56.1549      4.90      87.0       100.0
#
#    Wind Speed Country        Date
# 0        4.94      RU  1660179645
# 1       10.36      AR  1660179525
# 2        4.94      CL  1660179647
# 3        4.72      GL  1660179647
# 4        9.86      MV  1660179648
# 5       15.14      PF  1660179649
# 6        9.22      NU  1660179573
# 7        2.39      ZA  1660179438
# 8        2.84      AU  1660179650
# 9        7.29      GL  1660179652

# %% [markdown]
# ## Plotting the Data
# * Use proper labelling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
clean_city_data.count()
# Out:
# index         567
# City          567
# Lat           567
# Lng           567
# Max Temp      567
# Humidity      567
# Cloudiness    567
# Wind Speed    567
# Country       567
# Date          567
# dtype: int64

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_values = clean_city_data["Lat"]
y_values = clean_city_data["Humidity"]
plt.scatter(x_values, y_values)
plt.title("Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.show()

# %% [markdown]
# This plot is analysing the latitude v humidity. It does not really offer much informatin as it is very scattered. We can conclude that a majority of the world has humidity above 20.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_values = clean_city_data["Lat"]
y_values = clean_city_data["Cloudiness"]
plt.scatter(x_values, y_values)
plt.title("Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.show()

# %% [markdown]
# This scatter analyses Latitude v Cloudiness. We can see that there is high amount of cloudiness all around the world, however little at the northern and southern parts of the world.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_values = clean_city_data["Lat"]
y_values = clean_city_data["Wind Speed"]
plt.scatter(x_values, y_values)
plt.title("City Latitude vs Windspeed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.show()

# %% [markdown]
# This scatter analyses Latitude and wind speed. We can see that a large part of the world has wind speed less than 25 mph, and that latitude 35 to 65 has a huge amount of windspeed less than 15 mph.

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ###  Max Temp vs. Latitude Linear Regression

# %%
northern_hemisphere = clean_city_data[clean_city_data["Lat"]>0]
southern_hemisphere = clean_city_data[clean_city_data["Lat"]<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Max Temp"]
plt.scatter(x_values, y_values)
plt.title("Northern Hemisphere - Max Temp Vs Latitude ")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")

#Linear Regression
# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
# Get regression values
regress_values = x_values * slope + intercept
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,5),fontsize=15,color="red")
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# The r-value is: 0.45678999158472766

# %% [markdown]
# This linear regreesion model represents Northern hemisphere max temp v latitude. You can see that there seems to be a decline in max temp the more the latitude increases.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Max Temp"]
plt.scatter(x_values, y_values)
plt.title("Southern Hemisphere - Max Temp Vs Latitude ")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")

#Linear Regression
# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
# Get regression values
regress_values = x_values * slope + intercept
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,30),fontsize=15,color="red")
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# The r-value is: 0.7159247475674214

# %% [markdown]
# This linear regreesion model represents Southern hemisphere max temp v latitude. You can see that there seems to be an incline in max temp the more the latitude nears the equator.

# %% [markdown]
# ### Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Max Temp"]
plt.scatter(x_values, y_values)
plt.title("Northern Hemisphere - Humidity Vs Latitude ")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

#Linear Regression
# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
# Get regression values
regress_values = x_values * slope + intercept
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,5),fontsize=15,color="red")
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# The r-value is: 0.45678999158472766

# %% [markdown]
# This scatter represents the northern hemisphere latitude v humidity. We can see a weak correlation between the increase of latitude against the decrease of humidity.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Max Temp"]
plt.scatter(x_values, y_values)
plt.title("Southern Hemisphere - Humidity Vs Latitude ")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

#Linear Regression
# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
# Get regression values
regress_values = x_values * slope + intercept
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,30),fontsize=15,color="red")
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# The r-value is: 0.7159247475674214

# %% [markdown]
# This scatter represents the southern hemisphere latitude v humidity. We can see a strong correlation between the increase of latitude against the increase of humidity.

# %% [markdown]
# ### Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Cloudiness"]
plt.scatter(x_values, y_values)
plt.title("Northern Hemisphere - Cloudiness Vs Latitude ")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

#Linear Regression
# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
# Get regression values
regress_values = x_values * slope + intercept
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(2,5),fontsize=15,color="red")
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# The r-value is: 0.00016184166995727303

# %% [markdown]
# This scatter shows the Northern hemisphere Latitude v Cloudiness. It is scattered all over the plt, not giving us any solid correlations.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Cloudiness"]
plt.scatter(x_values, y_values)
plt.title("Southern Hemisphere - Cloudiness Vs Latitude ")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

#Linear Regression
# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
# Get regression values
regress_values = x_values * slope + intercept
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,20),fontsize=15,color="red")
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# The r-value is: 0.0035387830021920363

# %% [markdown]
# This scatter shows the Southern hemisphere Latitude v Cloudiness. It is scattered all over the plt, not giving us any solid correlations.

# %% [markdown]
# ### Wind Speed (m/s) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Wind Speed"]
plt.scatter(x_values, y_values)
plt.title("Northern Hemisphere - Wind Speed (mph) Vs Latitude ")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

#Linear Regression
# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
# Get regression values
regress_values = x_values * slope + intercept
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(30,32),fontsize=15,color="red")
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# The r-value is: 0.0010455616654046773

# %% [markdown]
# This is the northern hemisphere Latitude v Wind Speed (mph) scatter. There is no strong correlation, however we can see that a large part of the world has wind speed 20 mph or less.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Wind Speed"]
plt.scatter(x_values, y_values)
plt.title("Northern Hemisphere - Wind Speed (mph) Vs Latitude ")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

#Linear Regression
# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
# Get regression values
regress_values = x_values * slope + intercept
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# The r-value is: 0.0006870844863681099

# %% [markdown]
# This is the southern hemisphere Latitude v Wind Speed (mph) scatter. There is no strong correlation, however we can see that a large part of the world has wind speed 20 mph or less.
